# %% [markdown]
# # Aula 1
# Nesta aula é apresentado o jupyter notebook e os conceitos básicos na interface de programação

# %% [markdown]
# ## Comandos básicos e variáveis

# %%
# Declaração de variáveis em python

a = 1
b = 2

print('A é igual a:' + str(a))
print(a + b)
# Out:
# A é igual a:1
# 3
